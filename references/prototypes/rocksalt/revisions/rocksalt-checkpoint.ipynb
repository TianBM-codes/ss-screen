# %% [markdown]
# ## Screen end members
#
# Screen the end members using a rocksalt template

# %%
# %load_ext aiida
# %aiida
# Out:
# Loaded AiiDA DB environment - profile name: bit.

# %%
from ase.io import read
from mace.calculators import mace_mp
from ase.constraints import FixSymmetry
from ase.filters import FrechetCellFilter
from spglib import find_primitive
from ase import Atoms
from ase.optimize import FIRE
from aiida_vasp.workchains.v2 import VaspBandUpdater, VaspRelaxUpdater,VaspHybridBandUpdater

from aiida import orm

# %%
from aiida_grouppathx import GroupPathX
basepath = GroupPathX('hc-rocksalt')

# %%
def get_primitive_atoms(base):
    cell, pos, numbers = find_primitive((base.cell, base.get_scaled_positions(), base.numbers), 1e-2)
    return Atoms(cell=cell, scaled_positions=pos, numbers=numbers, pbc=True)
base = get_primitive_atoms(read('NaCl.cif'))
base.set_cell(base.cell * 1.1, scale_atoms=True)

# %%
def generate_rocksalt(a, b):
    atoms = base.copy()
    atoms.symbols[atoms.symbols == 'Na'] = 'He'
    atoms.symbols[atoms.symbols == 'Cl'] = 'Xe'
    atoms.symbols[atoms.symbols == 'He'] = a
    atoms.symbols[atoms.symbols == 'Xe'] = b
    return atoms

# %%
def get_rocksalt(a, b):
    atoms = generate_rocksalt(a, b)
    
    atoms.calc = mace_mp('medium')
    opt = FIRE(FrechetCellFilter(atoms))
    
    opt.run()
    atoms.calc = None
    return atoms

# %%
structpath = basepath['structures']
structpath.get_or_create_group()
# Out:
# (<Group: 'hc-rocksalt/structures' [type core], of user bzhu@bit.edu.cn>, False)

# %%
for A in ['Ge']:
    for B in ['S', 'Se', 'Te']:
        atoms = get_rocksalt(A, B)
        structure = orm.StructureData(ase=atoms)
        structure.label = f'{A}{B} INIT'
        structpath.add_node(structure.store(), structure.label.replace(' ', '_').lower())
# Out:
# Using Materials Project MACE for MACECalculator with /home/bonan/.cache/mace/20231203mace128L1_epoch199model
# Using float32 for MACECalculator, which is faster but less accurate. Recommended for MD. Use float64 for geometry optimization.
# Default dtype float32 does not match model dtype float64, converting models to float32.
#       Step     Time          Energy          fmax
# FIRE:    0 09:33:22       -8.175721        2.414452
# FIRE:    1 09:33:22       -8.343411        2.213952
# FIRE:    2 09:33:22       -8.623037        1.811091
# FIRE:    3 09:33:22       -8.916543        1.216704
# FIRE:    4 09:33:22       -9.097680        0.302391
# FIRE:    5 09:33:22       -9.025084        0.925449
# FIRE:    6 09:33:22       -9.031383        0.889457
# FIRE:    7 09:33:22       -9.043009        0.818691
# FIRE:    8 09:33:22       -9.058163        0.715595
# FIRE:    9 09:33:22       -9.074485        0.583932
# FIRE:   10 09:33:22       -9.089424        0.428922
# FIRE:   11 09:33:22       -9.100648        0.257441
# FIRE:   12 09:33:22       -9.106447        0.077825
# FIRE:   13 09:33:22       -9.105633        0.118744
# FIRE:   14 09:33:22       -9.105665        0.117403
# FIRE:   15 09:33:22       -9.105728        0.114735
# FIRE:   16 09:33:22       -9.105817        0.110767
# FIRE:   17 09:33:22       -9.105930        0.105539
# FIRE:   18 09:33:22       -9.106062        0.099111
# FIRE:   19 09:33:22       -9.106207        0.091550
# FIRE:   20 09:33:22       -9.106357        0.082937
# FIRE:   21 09:33:22       -9.106521        0.072302
# FIRE:   22 09:33:22       -9.106690        0.059375
# FIRE:   23 09:33:22       -9.106848        0.043915
# Using Materials Project MACE for MACECalculator with /home/bonan/.cache/mace/20231203mace128L1_epoch199model
# Using float32 for MACECalculator, which is faster but less accurate. Recommended for MD. Use float64 for geometry optimization.
# Default dtype float32 does not match model dtype float64, converting models to float32.
#       Step     Time          Energy          fmax
# FIRE:    0 09:33:22       -8.114361        1.648462
# FIRE:    1 09:33:22       -8.191939        1.489034
# FIRE:    2 09:33:22       -8.317968        1.190117
# FIRE:    3 09:33:22       -8.446248        0.786686
# FIRE:    4 09:33:22       -8.529278        0.283746
# FIRE:    5 09:33:22       -8.522437        0.411016
# FIRE:    6 09:33:22       -8.523680        0.395190
# FIRE:    7 09:33:22       -8.525976        0.364467
# FIRE:    8 09:33:22       -8.528983        0.320632
# FIRE:    9 09:33:22       -8.532263        0.266095
# FIRE:   10 09:33:22       -8.535357        0.203671
# FIRE:   11 09:33:22       -8.537854        0.136319
# FIRE:   12 09:33:22       -8.539449        0.066870
# FIRE:   13 09:33:22       -8.539961        0.009113
# Using Materials Project MACE for MACECalculator with /home/bonan/.cache/mace/20231203mace128L1_epoch199model
# Using float32 for MACECalculator, which is faster but less accurate. Recommended for MD. Use float64 for geometry optimization.
# Default dtype float32 does not match model dtype float64, converting models to float32.
#       Step     Time          Energy          fmax
# FIRE:    0 09:33:22       -7.851100        0.533974
# FIRE:    1 09:33:22       -7.859143        0.469924
# FIRE:    2 09:33:22       -7.871452        0.346964
# FIRE:    3 09:33:22       -7.882071        0.176037
# FIRE:    4 09:33:22       -7.885562        0.025072

# %%
def launch_hse06(node, label):
    """Generate process builder"""
    queue_name = 'xhhctdnormal'
    code = 'vasp-6.4.2@sugon-xh-v2'
    upd = VaspHybridBandUpdater().apply_preset(structure=node, overrides={
        'lhfcalc': True,
        'hfscreen': 0.2,
        'precfock': 'fast',
        'ispin': 1,
        'gga': None,  # PBE functional
        'magmom': None,
        'ncore': 2,
        'kpar': 16,
    },
         code=code, label=f'{node.get_formula()} {node.label}THSE06')
    upd.set_resources(num_machines=4, tot_num_mpiprocs=64)
    upd.set_options(max_wallclock_seconds=3600 * 48, queue_name=queue_name)
 
    # Only re-try twice if there is convergence problem
    upd.builder.scf.max_iterations = 2

    # Do relaxation - this is needed for getting the IBZKPT
    upd_relax = VaspRelaxUpdater(builder=upd.builder.relax)
    upd_relax.apply_preset(structure=node, overrides={
        #'metagga': 'mbj',
        'ispin': 1,
        'gga': None,
        'magmom': None,
        'ncore': 8,
    },
         code=code, label=f'{node.get_formula()} {node.label} PBE RELAX')
    upd_relax.set_resources(num_machines=1, tot_num_mpiprocs=32)
    upd_relax.set_options(max_wallclock_seconds=3600 * 12, queue_name=queue_name)
    #upd_relax.set_relax_settings(perform=False) # Not actually relaxing
    upd.set_band_settings(band_mode='bradcrack', line_density=15, kpoints_per_split=200)
    running = upd.submit()
    return running, label

# %%
def launch_hse06_soc(node, label):
    """Generate process builder"""
    queue_name = 'xhhctdnormal'
    code = 'vasp-6.4.2-ncl@sugon-xh-v2'
    upd = VaspHybridBandUpdater().apply_preset(structure=node, overrides={
        'lhfcalc': True,
        'hfscreen': 0.2,
        'precfock': 'fast',
        'ispin': None, # Use default
        'gga': None,  # PBE functional
        'magmom': None,
        'ncore': 2,
        'kpar': 16,
        'lsorbit': True,
    },
         code=code, label=f'{node.get_formula()} {node.label} HSE06 SOC')
    upd.set_resources(num_machines=4, tot_num_mpiprocs=64)
    upd.set_options(max_wallclock_seconds=3600 * 48, queue_name=queue_name)
 
    # Only re-try twice if there is convergence problem
    upd.builder.scf.max_iterations = 2

    # Do relaxation - this is needed for getting the IBZKPT
    upd_relax = VaspRelaxUpdater(builder=upd.builder.relax)
    upd_relax.apply_preset(structure=node, overrides={
        #'metagga': 'mbj',
        'ispin': 1,
        'gga': None,
        'magmom': None,
        'ncore': 8,
    },
         code=code, label=f'{node.get_formula()} {node.label} PBE RELAX')
    upd_relax.set_resources(num_machines=1, tot_num_mpiprocs=32)
    upd_relax.set_options(max_wallclock_seconds=3600 * 12, queue_name=queue_name)
    #upd_relax.set_relax_settings(perform=False) # Not actually relaxing
    upd.set_band_settings(band_mode='bradcrack', line_density=15, kpoints_per_split=200)
    running = upd.submit()
    return running, label

# %%
def launch_mbj_soc(node, label, soc=False):
    """Generate process builder"""
    queue_name = 'xhhctdnormal'
    code = 'vasp-6.4.2-ncl@sugon-xh-v2' if soc else 'vasp-6.4.2@sugon-xh-v2'
    worklabel = f'{node.get_formula()} {node.label} MBJ'
    if soc:
        worklabel += ' SOC'
    upd = VaspHybridBandUpdater().apply_preset(structure=node, overrides={
        'ispin': 1, # Use default
        'metagga': 'mbj',
        'gga': None,
        'ncore': 2,
        'kpar': 16,
        'lsorbit': True,
    },
         code=code, label=worklabel)
    upd.set_resources(num_machines=1, tot_num_mpiprocs=64)
    upd.set_options(max_wallclock_seconds=3600 * 48, queue_name=queue_name)
 
    # Only re-try twice if there is convergence problem
    upd.builder.scf.max_iterations = 2

    # Do relaxation - this is needed for getting the IBZKPT
    upd_relax = VaspRelaxUpdater(builder=upd.builder.relax)
    upd_relax.apply_preset(structure=node, overrides={
        #'metagga': 'mbj',
        'ispin': 1,
        'gga': None,
        'magmom': None,
        'ncore': 8,
    },
         code=code, label=worklabel + 'RELAX')
    upd_relax.set_resources(num_machines=1, tot_num_mpiprocs=32)
    upd_relax.set_options(max_wallclock_seconds=3600 * 12, queue_name=queue_name)
    #upd_relax.set_relax_settings(perform=False) # Not actually relaxing
    upd.set_band_settings(band_mode='bradcrack', line_density=15, kpoints_per_split=200)
    running = upd.submit()
    return running, label

# %%
workpath = basepath['mbj_bs']
workpath.get_or_create_group()

for path in structpath.fast_iter:
    if not 'init' in path.key:
        continue
    if workpath[path.key].get_node() is None:
        node = path.get_node()
        running, key = launch_mbj_soc(node, path.key, soc=False)
        workpath.add_node(running, key)
        print(path.key)

# %%
structpath.show_tree()
# Out:
# structures
# ├── cds_init *
# ├── cdse_init *
# ├── cdte_init *
# ├── ges_init *
# ├── gese_init *
# ├── gete_init *
# ├── hgs_init *
# ├── hgse_init *
# ├── hgte_init *
# ├── pbs_init *
# ├── pbse_init *
# ├── pbsete_0.25 *
# ├── pbsete_0.5 *
# ├── pbsete_0.75 *
# ├── pbte_init *
# ├── sns_init *
# ├── snse_init *
# ├── snte_init *
# ├── zns_init *
# ├── znse_init *
# └── znte_init *

# %%
for path in structpath.fast_iter:
    print(path.get_node().get_ase())
# Out:
# Atoms(symbols='PbS', pbc=True, cell=[[1.396960501967e-08, 3.0101859140123, 3.0101859296429], [3.010185919785, 7.7071623207272e-09, 3.0101859359054], [3.0101858977677, 3.0101858982574, 2.9724455098263e-08]], masses=...)
# Atoms(symbols='PbSe', pbc=True, cell=[[-9.603005278045e-10, 3.1224037118508, 3.1224037189832], [3.1224037184089, 5.4649275496927e-09, 3.122403712558], [3.122403715041, 3.1224037020578, 8.8327286319709e-09]], masses=...)
# Atoms(symbols='PbTe', pbc=True, cell=[[5.0217120291026e-08, 3.2892533762555, 3.2892533878901], [3.2892533985221, -1.6362612450629e-08, 3.2892534544699], [3.2892533632764, 3.2892534075896, 1.8883065328212e-08]], masses=...)
# Atoms(symbols='SnS', pbc=True, cell=[[8.038178819687e-10, 2.9241518066619, 2.9241518208077], [2.9241518288028, 7.6855236126441e-10, 2.924151820843], [2.9241518170184, 2.9241517949128, 1.2552939948272e-08]], masses=...)
# Atoms(symbols='SnSe', pbc=True, cell=[[-1.3694707437256e-10, 3.0221630194599, 3.0221630176991], [3.0221629868219, 1.9149462798584e-08, 3.0221629984127], [3.022163007156, 3.0221630205076, -1.1846334890927e-09]], masses=...)
# Atoms(symbols='SnTe', pbc=True, cell=[[-3.5797179590922e-09, 3.2007100886891, 3.2007100831861], [3.200710079665, -1.4909042445969e-10, 3.2007100797555], [3.2007100649662, 3.2007100705597, 1.4549709166038e-08]], masses=...)
# Atoms(symbols='CdS', pbc=True, cell=[[-2.526112988328e-08, 2.7562438599701, 2.7562438504536], [2.7562438261307, -2.1954552404903e-09, 2.7562438273879], [2.7562438501434, 2.7562438609171, -2.6208165573304e-08]], masses=...)
# Atoms(symbols='CdSe', pbc=True, cell=[[-1.4071549683048e-08, 2.8789386973445, 2.8789386879875], [2.8789386964798, -1.3493723775503e-08, 2.8789386874097], [2.8789386903249, 2.8789386906118, -7.3389112448606e-09]], masses=...)
# Atoms(symbols='CdTe', pbc=True, cell=[[-9.114272298382e-10, 3.0743193299682, 3.0743193304878], [3.0743193282917, -3.7786019660193e-10, 3.0743193299542], [3.0743193305956, 3.0743193317385, -2.681729092526e-09]], masses=...)
# Atoms(symbols='ZnS', pbc=True, cell=[[-1.1078911135554e-08, 2.5603423392555, 2.5603423109024], [2.5603423632928, -1.8190242996742e-08, 2.5603423180137], [2.5603423633676, 2.5603423464417, -1.8265095289982e-08]], masses=...)
# Atoms(symbols='ZnSe', pbc=True, cell=[[4.8542994740397e-08, 2.6993151344733, 2.6993150214125], [2.6993151364418, 5.6304944955986e-08, 2.6993150136505], [2.699315140889, 2.6993151311586, 5.1857653914214e-08]], masses=...)
# Atoms(symbols='ZnTe', pbc=True, cell=[[3.5653515051265e-09, 2.8903709108025, 2.8903709186257], [2.8903709489397, -9.4553886404889e-09, 2.8903709316464], [2.8903709100456, 2.8903708849291, 2.9438706514666e-08]], masses=...)
# Atoms(symbols='HgS', pbc=True, cell=[[-2.6370600879803e-09, 2.8162520848515, 2.8162520699455], [2.816252003718, -6.2395623775315e-10, 2.8162520679324], [2.8162520059001, 2.8162520850206, -2.8061289121559e-09]], masses=...)
# Atoms(symbols='HgSe', pbc=True, cell=[[-1.9686347783519e-08, 2.9135504180317, 2.9135504391507], [2.9135504054649, -3.5187617963643e-09, 2.9135504229831], [2.9135504098905, 2.9135504062897, -7.9443788785389e-09]], masses=...)
# Atoms(symbols='HgTe', pbc=True, cell=[[-3.162765385396e-09, 3.0823880766137, 3.0823880780352], [3.0823880660145, -1.59083403826e-09, 3.0823880764633], [3.082388064757, 3.0823880737842, -3.3327581480659e-10]], masses=...)

# %%
for path in workpath:
    print(path.get_node().is_finished_ok, path.key)
# Out:
# True pbs_init
# True pbse_init
# True pbte_init
# True sns_init
# True snse_init
# True snte_init
# True cds_init
# True cdse_init
# True cdte_init
# True zns_init
# True znse_init
# True znte_init
# True hgs_init
# True hgse_init
# True hgte_init

# %%
def show_bands(worknode):
    from aiida_vasp.utils.sumo import get_sumo_bands_plotter
    plotter = get_sumo_bands_plotter(worknode.outputs.band_structure,
                                     structure=worknode.outputs.primitive_structure)
    return plotter

# %%
workpath = basepath['hse06_bs_soc']
for path in workpath:
    node = path.get_node()
    plotter = show_bands(node)
    gap = plotter.bs.get_band_gap()['energy']
    plotter.get_plot(title=node.label.split()[0] + f' Band Gap: {gap:.3f} eV SOC')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/aiida/lib/python3.12/site-packages/aiida/orm/utils/managers.py:88, in NodeLinksManager._get_node_by_link_label(self, label)
#      87 try:
# ---> 88     node = attribute_dict[label]
#      89 except KeyError as exception:
#      90     # Check whether the label contains a double underscore, in which case we want to warn the user that this is
#      91     # deprecated. However, we need to exclude labels that corresponds to dunder methods, i.e., those that start
#      92     # and end with a double underscore.
#
# KeyError: 'band_structure'
#
# The above exception was the direct cause of the following exception:
#
# NotExistent                               Traceback (most recent call last)
# File ~/miniconda3/envs/aiida/lib/python3.12/site-packages/aiida/orm/utils/managers.py:133, in NodeLinksManager.__getattr__(self, name)
#     132 try:
# --> 133     return self._get_node_by_link_label(label=name)
#     134 except NotExistent as exception:
#     135     # Note: in order for TAB-completion to work, we need to raise an exception that also inherits from
#     136     # `AttributeError`, so that `getattr(node.inputs, 'some_label', some_default)` returns `some_default`.
#     137     # Otherwise, the exception is not caught by `getattr` and is propagated, instead of returning the default.
#
# File ~/miniconda3/envs/aiida/lib/python3.12/site-packages/aiida/orm/utils/managers.py:116, in NodeLinksManager._get_node_by_link_label(self, label)
#     115             raise NotExistent from exc
# --> 116     raise NotExistent from exception
#     118 return node
#
# NotExistent:
#
# The above exception was the direct cause of the following exception:
#
# NotExistentAttributeError                 Traceback (most recent call last)
# Cell In[111], line 4
#       2 for path in workpath:
#       3     node = path.get_node()
# ----> 4     plotter = show_bands(node)
#       5     gap = plotter.bs.get_band_gap()['energy']
#       6     plotter.get_plot(title=node.label.split()[0] + f' Band Gap: {gap:.3f} eV SOC')
#
# Cell In[96], line 3, in show_bands(worknode)
#       1 def show_bands(worknode):
#       2     from aiida_vasp.utils.sumo import get_sumo_bands_plotter
# ----> 3     plotter = get_sumo_bands_plotter(worknode.outputs.band_structure,
#       4                                      structure=worknode.outputs.primitive_structure)
#       5     return plotter
#
# File ~/miniconda3/envs/aiida/lib/python3.12/site-packages/aiida/orm/utils/managers.py:139, in NodeLinksManager.__getattr__(self, name)
#     134 except NotExistent as exception:
#     135     # Note: in order for TAB-completion to work, we need to raise an exception that also inherits from
#     136     # `AttributeError`, so that `getattr(node.inputs, 'some_label', some_default)` returns `some_default`.
#     137     # Otherwise, the exception is not caught by `getattr` and is propagated, instead of returning the default.
#     138     prefix = 'input' if self._incoming else 'output'
# --> 139     raise NotExistentAttributeError(
#     140         f"Node<{self._node.pk}> does not have an {prefix} with link label '{name}'"
#     141     ) from exception
#
# NotExistentAttributeError: Node<607253> does not have an output with link label 'band_structure'

# %%
workpath = basepath['hse06_bs']
for path in workpath:
    node = path.get_node()
    plotter = show_bands(node)
    gap = plotter.bs.get_band_gap()['energy']
    plotter.get_plot(title=node.label.split()[0] + f' Band Gap: {gap:.3f} eV')
