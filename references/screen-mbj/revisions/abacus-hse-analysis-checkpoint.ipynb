# %%
# %load_ext aiida
# %aiida

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from aiida import orm
from monty.serialization import loadfn, dumpfn
import numpy as np
from aiida_vasp.workchains import VaspHybridBandsWorkChain
from aiida_vasp.workchains.v2 import VaspHybridBandUpdater, VaspRelaxUpdater
from aiida_grouppathx import GroupPathX
from tqdm import tqdm
from aiida_grouppathx import GroupPathX

from aiida_user_addons.tools.sumo import get_sumo_bands_plotter, get_pmg_bandstructure

import pandas as pd

from aiida_vasp.utils.compare_bands import get_band_properties_from_data

# %%
basepath = GroupPathX('hc-binary-hse-abacus')
workpath = basepath['bandstructure_works']
nodes = [path.get_node() for path in workpath]
finished_ok = list(filter(lambda x: x.is_finished_ok, nodes))

# %%
def show_bands(worknode):
    plotter = get_sumo_bands_plotter(worknode.outputs.band_structure, structure=worknode.outputs.primitive_structure)
    return plotter

# %%
records = []
for node in tqdm(finished_ok):
    bs = get_pmg_bandstructure(node.outputs.band_structure, node.outputs.primitive_structure)
    band_info = bs.get_band_gap()  # Using pymatgen band gap information which is more robust than that shipped in AiiDA vasp
    band_info['band_gap'] = band_info.pop('energy')
    out_dict =     {
        'structure': node.inputs.structure.get_pymatgen(),
        'formula': node.inputs.structure.get_formula(),
        'material_id': node.label.split()[0],
        'uuid': node.uuid,
    }
    out_dict.update(band_info)
    records.append(
        out_dict
)
df = pd.DataFrame.from_records(records)

# %%
df[df.direct == True].sort_values('band_gap')
# Out:
#                                              structure formula material_id  \
# 89   [[0. 0. 0.] Ge, [4.00252088 2.31085652 1.63374...    GeSe   wbm-20074
# 34   [[0. 0. 0.] Ga, [1.25275264 0.88582964 2.16983...    GaSb     mp-1156
# 40   [[-3.09500995 -3.29645023  1.51262885] Se, [-1...    SeSn  wbm-107127
# 42   [[-0.81023595  1.96013787  3.29608906] Sn, [ 0...    SnTe   wbm-56490
# 50   [[0. 0. 0.] Sn, [2.60120575 1.83933005 4.50542...    SnTe     mp-1883
# 65   [[4.52226069 2.61092843 1.66589871] Te, [2.261...    SnTe   wbm-56491
# 53   [[0. 0. 0.] Ga, [1.173751   0.82996725 2.03299...    AsGa     mp-2534
# 76   [[0. 0. 0.] As, [ 2.03218308e+00 -2.22044605e-...    AsGa   wbm-18603
# 100  [[0. 0. 0.] Ge, [4.24979984 2.45362308 1.73497...    GeTe   wbm-20160
# 48   [[ 0.00000000e+00 -2.22044605e-16  2.13871705e...    PbSe   wbm-53026
# 67   [[-1.05342416 -3.24405789  1.55095566] Pb, [ 1...    PbSe   wbm-53023
# 92   [[0. 0. 0.] Pb, [2.52364663 1.78448768 4.37108...    PbSe     mp-2201
# 17   [[ 3.29259314 -1.09751688 -1.55177994] Pb, [ 1...    PbSe   wbm-53024
# 80   [[1.09774964 1.09774964 1.55120136] Pb, [ 1.09...    PbSe   wbm-53019
# 63   [[5.96268927 3.44256026 0.06511301] Ge, [3.975...    GeSe   wbm-20073
# 44   [[1.8226612  1.0521475  0.74397989] O, [3.6453...     CdO   wbm-43911
# 69   [[1.05762679 1.4956237  3.16244772] Pb, [-1.05...     PbS    mp-21276
# 58   [[-3.18011076 -1.49887368  1.06073987] Pb, [-1...     PbS   wbm-50759
# 81   [[0. 0. 0.] Pb, [-2.49999998e-09  1.93262500e-...     PbS   wbm-50757
# 31   [[0. 0. 0.] Cd, [ 0.          2.19234019 -1.54...    CdSe   wbm-52959
# 180  [[3.28447625 0.62009144 6.26559097] Se, [-1.06...  Cd2Se2   wbm-52961
# 205  [[2.1730453  1.25460538 3.54458927] Cd, [-1.83...  Cd2Se2     mp-1070
# 64   [[0. 0. 0.] Te, [2.6706764  1.88845311 4.62574...    PbTe    mp-19717
# 3    [[ 1.55867416  2.69961619 -0.305298  ] Cd, [1....    CdTe    wbm-9589
# 22   [[0. 0. 0.] Cd, [1.33991689 0.94746463 2.32080...    CdTe      mp-406
# 88   [[-1.52225508e-04  3.30615030e+00 -3.30724596e...    CdTe    wbm-9588
# 286  [[0. 0. 0.] Se, [4.14246632 4.14246632 1.96029...   I4Se2   mp-861871
# 297  [[1.60374989 2.38191803 2.38290002] Sn, [0. 0....   O4Sn2      mp-856
# 73   [[1.96705265 1.08045479 0.98229077] Cu, [0. 0....    BrCu    mp-22913
# 85   [[0.13404991 0.10476563 0.00155342] Cl, [ 2.06...    ClCu   wbm-10880
# 12   [[ 0.04534979 -0.02734484  2.34252368] Cu, [ 1...    ClCu   wbm-10871
# 373  [[1.90790051 1.10116221 2.38684483] Cu, [3.815...  Cl4Cu4   wbm-10875
# 215  [[1.90530278 1.10002705 3.95529341] Cu, [-1.57...  Cl2Cu2   wbm-10877
#
#                                      uuid  direct     transition  band_gap
# 89   241233a9-edc2-46bb-90f0-14932931e6fa    True            L-L   0.20136
# 34   83289504-663a-4cb7-b2a0-d57204658193    True  \Gamma-\Gamma   0.25945
# 40   4302ca6b-43c0-436a-ad8e-5810df1502c3    True        L_2-L_2   0.26074
# 42   919daaf7-b30c-4307-8464-e42c28e2e595    True            L-L   0.40261
# 50   52f294a1-e337-4cf1-9d47-c6f8675cd188    True            L-L   0.41663
# 65   59131d23-e61f-4875-bfc0-93de3bb7a079    True            L-L   0.52977
# 53   50398d78-bc2a-4209-876b-717cb7dbb08e    True  \Gamma-\Gamma   0.61736
# 76   9d138d0f-61a4-40b8-a19d-a946f7b5271d    True  \Gamma-\Gamma   0.62320
# 100  6acc700b-b611-4b8e-a751-05d5d2ab50a9    True            L-L   0.65430
# 48   59a200bd-5b4f-4c1f-bef6-e5708c82dd49    True            L-L   0.70354
# 67   d721fd5f-ee79-4a61-acfd-d0d635f642e8    True            L-L   0.70373
# 92   87ca8809-3df0-4552-ad21-2e5db68a9730    True            L-L   0.70390
# 17   f0fb0df2-788e-48fd-95e0-5b6c6d0a4ba3    True            L-L   0.70414
# 80   55d65fec-b60a-4b7e-bb26-b8c368cd228c    True            L-L   0.70442
# 63   a70ce14c-ffae-4cb5-9d94-7567d0c00b22    True            L-L   0.71620
# 44   cee48db7-7613-4969-9ad7-fbcb966bf65e    True  \Gamma-\Gamma   0.73398
# 69   28d45ffa-0a26-4f93-a88b-cf7db7fa64c0    True            L-L   0.77658
# 58   43147848-ad27-4b34-b070-754034f2369e    True            L-L   0.77683
# 81   0d31f625-fa33-45ec-b3a7-75825b4d1247    True            L-L   0.77840
# 31   8855d761-88e2-4cc5-8426-69b1ec1f18b6    True  \Gamma-\Gamma   1.12545
# 180  93aee17f-cb25-4cb1-b9d7-01f738fb39b6    True  \Gamma-\Gamma   1.15224
# 205  8d186dee-6711-4a42-b66e-be3b4330c074    True  \Gamma-\Gamma   1.18023
# 64   274aa5a4-7daa-43a8-9a99-95f83234aba6    True            L-L   1.21713
# 3    6bf8cdad-dc96-4244-952c-78298e72a347    True  \Gamma-\Gamma   1.28501
# 22   d59d52fe-bf95-4897-8a13-efe70c59ae38    True  \Gamma-\Gamma   1.28603
# 88   050fcc27-ea70-4eda-937a-b53c2bdd805e    True  \Gamma-\Gamma   1.28700
# 286  c761006b-eb4d-46a0-b7dd-4cea75d5f362    True            X-X   1.65251
# 297  40388821-648c-4e65-a46f-ca8f1b578109    True  \Gamma-\Gamma   1.77453
# 73   947753cf-4d40-44da-a2d1-5af1c8b9a7ce    True  \Gamma-\Gamma   2.05032
# 85   0e3bd0c2-f7fe-41eb-9607-7adbb52b4a01    True  \Gamma-\Gamma   2.25616
# 12   f44d7763-b9fa-42e1-9b0e-3da242b0d8a1    True  \Gamma-\Gamma   2.25625
# 373  f74eb593-5ab2-4e22-bf7c-3706200e1d8f    True  \Gamma-\Gamma   2.27841
# 215  ed0f4511-99a8-4e4e-8128-67079bf95792    True  \Gamma-\Gamma   2.29571

# %%
df[df.direct == True].sort_values('band_gap')
# Out:
#                                              structure formula material_id  \
# 89   [[0. 0. 0.] Ge, [4.00252088 2.31085652 1.63374...    GeSe   wbm-20074
# 34   [[0. 0. 0.] Ga, [1.25275264 0.88582964 2.16983...    GaSb     mp-1156
# 40   [[-3.09500995 -3.29645023  1.51262885] Se, [-1...    SeSn  wbm-107127
# 42   [[-0.81023595  1.96013787  3.29608906] Sn, [ 0...    SnTe   wbm-56490
# 50   [[0. 0. 0.] Sn, [2.60120575 1.83933005 4.50542...    SnTe     mp-1883
# 65   [[4.52226069 2.61092843 1.66589871] Te, [2.261...    SnTe   wbm-56491
# 53   [[0. 0. 0.] Ga, [1.173751   0.82996725 2.03299...    AsGa     mp-2534
# 76   [[0. 0. 0.] As, [ 2.03218308e+00 -2.22044605e-...    AsGa   wbm-18603
# 100  [[0. 0. 0.] Ge, [4.24979984 2.45362308 1.73497...    GeTe   wbm-20160
# 48   [[ 0.00000000e+00 -2.22044605e-16  2.13871705e...    PbSe   wbm-53026
# 67   [[-1.05342416 -3.24405789  1.55095566] Pb, [ 1...    PbSe   wbm-53023
# 92   [[0. 0. 0.] Pb, [2.52364663 1.78448768 4.37108...    PbSe     mp-2201
# 17   [[ 3.29259314 -1.09751688 -1.55177994] Pb, [ 1...    PbSe   wbm-53024
# 80   [[1.09774964 1.09774964 1.55120136] Pb, [ 1.09...    PbSe   wbm-53019
# 63   [[5.96268927 3.44256026 0.06511301] Ge, [3.975...    GeSe   wbm-20073
# 44   [[1.8226612  1.0521475  0.74397989] O, [3.6453...     CdO   wbm-43911
# 69   [[1.05762679 1.4956237  3.16244772] Pb, [-1.05...     PbS    mp-21276
# 58   [[-3.18011076 -1.49887368  1.06073987] Pb, [-1...     PbS   wbm-50759
# 81   [[0. 0. 0.] Pb, [-2.49999998e-09  1.93262500e-...     PbS   wbm-50757
# 31   [[0. 0. 0.] Cd, [ 0.          2.19234019 -1.54...    CdSe   wbm-52959
# 180  [[3.28447625 0.62009144 6.26559097] Se, [-1.06...  Cd2Se2   wbm-52961
# 205  [[2.1730453  1.25460538 3.54458927] Cd, [-1.83...  Cd2Se2     mp-1070
# 64   [[0. 0. 0.] Te, [2.6706764  1.88845311 4.62574...    PbTe    mp-19717
# 3    [[ 1.55867416  2.69961619 -0.305298  ] Cd, [1....    CdTe    wbm-9589
# 22   [[0. 0. 0.] Cd, [1.33991689 0.94746463 2.32080...    CdTe      mp-406
# 88   [[-1.52225508e-04  3.30615030e+00 -3.30724596e...    CdTe    wbm-9588
# 286  [[0. 0. 0.] Se, [4.14246632 4.14246632 1.96029...   I4Se2   mp-861871
# 297  [[1.60374989 2.38191803 2.38290002] Sn, [0. 0....   O4Sn2      mp-856
# 73   [[1.96705265 1.08045479 0.98229077] Cu, [0. 0....    BrCu    mp-22913
# 85   [[0.13404991 0.10476563 0.00155342] Cl, [ 2.06...    ClCu   wbm-10880
# 12   [[ 0.04534979 -0.02734484  2.34252368] Cu, [ 1...    ClCu   wbm-10871
# 373  [[1.90790051 1.10116221 2.38684483] Cu, [3.815...  Cl4Cu4   wbm-10875
# 215  [[1.90530278 1.10002705 3.95529341] Cu, [-1.57...  Cl2Cu2   wbm-10877
#
#      direct     transition  band_gap
# 89     True            L-L   0.20136
# 34     True  \Gamma-\Gamma   0.25945
# 40     True        L_2-L_2   0.26074
# 42     True            L-L   0.40261
# 50     True            L-L   0.41663
# 65     True            L-L   0.52977
# 53     True  \Gamma-\Gamma   0.61736
# 76     True  \Gamma-\Gamma   0.62320
# 100    True            L-L   0.65430
# 48     True            L-L   0.70354
# 67     True            L-L   0.70373
# 92     True            L-L   0.70390
# 17     True            L-L   0.70414
# 80     True            L-L   0.70442
# 63     True            L-L   0.71620
# 44     True  \Gamma-\Gamma   0.73398
# 69     True            L-L   0.77658
# 58     True            L-L   0.77683
# 81     True            L-L   0.77840
# 31     True  \Gamma-\Gamma   1.12545
# 180    True  \Gamma-\Gamma   1.15224
# 205    True  \Gamma-\Gamma   1.18023
# 64     True            L-L   1.21713
# 3      True  \Gamma-\Gamma   1.28501
# 22     True  \Gamma-\Gamma   1.28603
# 88     True  \Gamma-\Gamma   1.28700
# 286    True            X-X   1.65251
# 297    True  \Gamma-\Gamma   1.77453
# 73     True  \Gamma-\Gamma   2.05032
# 85     True  \Gamma-\Gamma   2.25616
# 12     True  \Gamma-\Gamma   2.25625
# 373    True  \Gamma-\Gamma   2.27841
# 215    True  \Gamma-\Gamma   2.29571

# %%
df[df.formula == 'InSb'].sort_values('band_gap')
# Out:
#                                            structure formula material_id  \
# 5  [[0. 0. 0.] In, [1.35400075 0.957423   2.34519...    InSb    mp-20012
#
#                                    uuid  direct transition  band_gap
# 5  fd80dfe3-6442-4d58-90ce-7ce279b330fc   False       None       0.0

# %%
show_bands(load_node('fd80dfe3-6442-4d58-90ce-7ce279b330fc')).get_plot(ymin=-1, ymax=1)
# Out:
# <module 'matplotlib.pyplot' from '/home/bonan/miniconda3/envs/aiida/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
#df.pop('structure', None)

df = df.sort_values('band_gap')
df.drop(['structure'], axis=1).to_csv('abacus_hse_gaps_binary_2025_0528_pmg_info.csv')
