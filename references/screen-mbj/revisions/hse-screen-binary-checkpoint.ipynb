# %%
# %load_ext aiida
# %aiida
# Out:
# Loaded AiiDA DB environment - profile name: bit.

# %%
from aiida import orm
from monty.serialization import loadfn, dumpfn
import numpy as np
from aiida_vasp.workchains import VaspHybridBandsWorkChain
from aiida_vasp.workchains.v2 import VaspHybridBandUpdater, VaspRelaxUpdater
from aiida_grouppathx import GroupPathX
from tqdm import tqdm

# %%
# Load the structures to be calculated
dataset = loadfn('binary_mbj_calc_structures_2025_03_19.json')
print(len(dataset))
# Out:
# 665

# %%
basepath = GroupPathX('hc-binary-mbj')
structpath = basepath['structures']

# %% [markdown]
# Deposit the structures

# %% [raw]
# for key, value in tqdm(dataset.items()):
#     node = orm.StructureData(pymatgen=value).store()
#     structpath.add_node(node, key)
#
# for key in structpath:
#     key.get_node().label = key.key

# %% [markdown]
# Sort the nodes based on their number of sites

# %%
nodes = [x.get_node() for x in structpath]
nodes.sort(key=lambda x: len(x.sites))

# %%
nodes[-1].get_ase()
# Out:
# Atoms(symbols='Ru4F24', pbc=True, cell=[[0.0, 0.0, -4.82221923], [0.0, -8.38575766, 0.0], [-9.05755894, 0.0, 0.0]], masses=...)

# %% [markdown]
# ## Setting up the calculation

# %%
def callback(node, label):
    """Generate process builder"""
    queue_name = 'tyhcnormal'
    upd = VaspHybridBandUpdater().apply_preset(structure=node, overrides={
        'metagga': 'mbj',
        'ispin': 2,
        'gga': None,  # PBE functional
        'magmom': None,
        'ncore': 8,
    },
         code='vasp-6.4.2@sugon-tai', label=f'{node.get_formula()} {node.label} MP STRUCT MBJ NORELAX')
    upd.set_resources(num_machines=1, tot_num_mpiprocs=64)
    upd.set_options(max_wallclock_seconds=3600 * 48, queue_name=queue_name)
    # Reuse WAVECAR for the mbj band structure calculation
    upd.set_band_settings(hybrid_reuse_wavecar=True)
    
    # Only re-try twice if there is convergence problem
    upd.builder.scf.max_iterations = 2

    # Do relaxation - this is needed for getting the IBZKPT
    upd_relax = VaspRelaxUpdater(builder=upd.builder.relax)
    upd_relax.apply_preset(structure=node, overrides={
        #'metagga': 'mbj',
        'ispin': 2,
        'gga': None,
        'magmom': None,
        'ncore': 8,
    },
         code='vasp-6.4.2@sugon-tai', label=f'{node.get_formula()} {node.label} MP STRUCT SP')
    upd_relax.set_resources(num_machines=1, tot_num_mpiprocs=32)
    upd_relax.set_options(max_wallclock_seconds=3600 * 12, queue_name=queue_name)
    upd_relax.set_relax_settings(perform=False) # Not actually relaxing
    
    upd.set_band_settings(band_mode='bradcrack', line_density=20, kpoints_per_split=200)
    running = upd.submit()
    return running, label

# %%
workpath = basepath['bandstructure_works']
workpath.get_or_create_group()
# Out:
# (<Group: 'hc-binary-mbj/bandstructure_works' [type core], of user bzhu@bit.edu.cn>,
#  False)

# %%
from aiida_grouppathx.launch_manager import GroupLauncher

# %%
launcher = GroupLauncher(workpath, 55, callback, source_key_obj_pairs=[(node.label, node) for node in nodes], logfile='launch_2025_4_6.log')

# %%
launcher.launch_loop()
# Out:
# Total number of running jobs: 60
# Total number of jobs to run : 306
# Time elapsed to gather jobs: 0.27 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 306
# Time elapsed to gather jobs: 0.25 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 305
# Time elapsed to gather jobs: 0.18 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 301
# Time elapsed to gather jobs: 0.20 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 49
# Total number of jobs to run : 298
# Time elapsed to gather jobs: 0.20 seconds
# Launching 6 jobs...
# Launched 6 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 292
# Time elapsed to gather jobs: 0.20 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 288
# Time elapsed to gather jobs: 0.28 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 285
# Time elapsed to gather jobs: 0.22 seconds
# Total number of running jobs: 52
# Total number of jobs to run : 285
# Time elapsed to gather jobs: 0.20 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 282
# Time elapsed to gather jobs: 0.20 seconds
# Total number of running jobs: 51
# Total number of jobs to run : 282
# Time elapsed to gather jobs: 0.21 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 278
# Time elapsed to gather jobs: 0.23 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 276
# Time elapsed to gather jobs: 0.29 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 273
# Time elapsed to gather jobs: 0.22 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 272
# Time elapsed to gather jobs: 0.23 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 48
# Total number of jobs to run : 270
# Time elapsed to gather jobs: 0.21 seconds
# Launching 7 jobs...
# Launched 7 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 263
# Time elapsed to gather jobs: 0.27 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 262
# Time elapsed to gather jobs: 0.25 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 258
# Time elapsed to gather jobs: 0.22 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 254
# Time elapsed to gather jobs: 0.22 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 253
# Time elapsed to gather jobs: 0.20 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 250
# Time elapsed to gather jobs: 0.26 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 246
# Time elapsed to gather jobs: 0.26 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 244
# Time elapsed to gather jobs: 0.21 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 243
# Time elapsed to gather jobs: 0.25 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 239
# Time elapsed to gather jobs: 0.21 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 237
# Time elapsed to gather jobs: 0.25 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 236
# Time elapsed to gather jobs: 0.24 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 50
# Total number of jobs to run : 235
# Time elapsed to gather jobs: 0.22 seconds
# Launching 5 jobs...
# Launched 5 jobs...
# Total number of running jobs: 50
# Total number of jobs to run : 230
# Time elapsed to gather jobs: 0.28 seconds
# Launching 5 jobs...
# Launched 5 jobs...
# Total number of running jobs: 50
# Total number of jobs to run : 225
# Time elapsed to gather jobs: 0.29 seconds
# Launching 5 jobs...
# Launched 5 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 220
# Time elapsed to gather jobs: 0.25 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 217
# Time elapsed to gather jobs: 0.27 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 216
# Time elapsed to gather jobs: 0.24 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 215
# Time elapsed to gather jobs: 0.24 seconds
# Total number of running jobs: 53
# Total number of jobs to run : 215
# Time elapsed to gather jobs: 0.26 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 213
# Time elapsed to gather jobs: 0.26 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 212
# Time elapsed to gather jobs: 0.27 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 211
# Time elapsed to gather jobs: 0.22 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 207
# Time elapsed to gather jobs: 0.25 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 206
# Time elapsed to gather jobs: 0.28 seconds
# Total number of running jobs: 50
# Total number of jobs to run : 206
# Time elapsed to gather jobs: 0.25 seconds
# Launching 5 jobs...
# Launched 5 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 201
# Time elapsed to gather jobs: 0.34 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 199
# Time elapsed to gather jobs: 0.29 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 199
# Time elapsed to gather jobs: 0.29 seconds
# Total number of running jobs: 53
# Total number of jobs to run : 199
# Time elapsed to gather jobs: 0.29 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 50
# Total number of jobs to run : 197
# Time elapsed to gather jobs: 0.30 seconds
# Launching 5 jobs...
# Launched 5 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 192
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 53
# Total number of jobs to run : 192
# Time elapsed to gather jobs: 0.30 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 190
# Time elapsed to gather jobs: 0.27 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 189
# Time elapsed to gather jobs: 0.27 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 185
# Time elapsed to gather jobs: 0.28 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 183
# Time elapsed to gather jobs: 0.31 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 180
# Time elapsed to gather jobs: 0.27 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 49
# Total number of jobs to run : 179
# Time elapsed to gather jobs: 0.25 seconds
# Launching 6 jobs...
# Launched 6 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 173
# Time elapsed to gather jobs: 0.28 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 173
# Time elapsed to gather jobs: 0.30 seconds
# Total number of running jobs: 53
# Total number of jobs to run : 173
# Time elapsed to gather jobs: 0.36 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 171
# Time elapsed to gather jobs: 0.29 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 171
# Time elapsed to gather jobs: 0.27 seconds
# Total number of running jobs: 51
# Total number of jobs to run : 171
# Time elapsed to gather jobs: 0.25 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 167
# Time elapsed to gather jobs: 0.26 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 167
# Time elapsed to gather jobs: 0.31 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 167
# Time elapsed to gather jobs: 0.25 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 167
# Time elapsed to gather jobs: 0.24 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 167
# Time elapsed to gather jobs: 0.28 seconds
# Total number of running jobs: 48
# Total number of jobs to run : 167
# Time elapsed to gather jobs: 0.29 seconds
# Launching 7 jobs...
# Launched 7 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 160
# Time elapsed to gather jobs: 0.27 seconds
# Total number of running jobs: 51
# Total number of jobs to run : 160
# Time elapsed to gather jobs: 0.26 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 156
# Time elapsed to gather jobs: 0.30 seconds
# Total number of running jobs: 52
# Total number of jobs to run : 156
# Time elapsed to gather jobs: 0.28 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 153
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 152
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 53
# Total number of jobs to run : 152
# Time elapsed to gather jobs: 0.27 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 150
# Time elapsed to gather jobs: 0.31 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 148
# Time elapsed to gather jobs: 0.26 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 144
# Time elapsed to gather jobs: 0.29 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 141
# Time elapsed to gather jobs: 0.32 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 139
# Time elapsed to gather jobs: 0.31 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 137
# Time elapsed to gather jobs: 0.31 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 135
# Time elapsed to gather jobs: 0.33 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 133
# Time elapsed to gather jobs: 0.30 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 132
# Time elapsed to gather jobs: 0.33 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 129
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 52
# Total number of jobs to run : 129
# Time elapsed to gather jobs: 0.34 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 51
# Total number of jobs to run : 126
# Time elapsed to gather jobs: 0.29 seconds
# Launching 4 jobs...
# Launched 4 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 122
# Time elapsed to gather jobs: 0.27 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 120
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 52
# Total number of jobs to run : 120
# Time elapsed to gather jobs: 0.31 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 117
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 116
# Time elapsed to gather jobs: 0.28 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 115
# Time elapsed to gather jobs: 0.28 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 115
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 114
# Time elapsed to gather jobs: 0.28 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 112
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 112
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 112
# Time elapsed to gather jobs: 0.34 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 111
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 111
# Time elapsed to gather jobs: 0.29 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 110
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 53
# Total number of jobs to run : 110
# Time elapsed to gather jobs: 0.35 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 108
# Time elapsed to gather jobs: 0.32 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 106
# Time elapsed to gather jobs: 0.28 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 106
# Time elapsed to gather jobs: 0.36 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 105
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 105
# Time elapsed to gather jobs: 0.28 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 104
# Time elapsed to gather jobs: 0.32 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 101
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 101
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 101
# Time elapsed to gather jobs: 0.33 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 100
# Time elapsed to gather jobs: 0.29 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 97
# Time elapsed to gather jobs: 0.43 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 96
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 95
# Time elapsed to gather jobs: 0.33 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 93
# Time elapsed to gather jobs: 0.35 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 91
# Time elapsed to gather jobs: 0.38 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 90
# Time elapsed to gather jobs: 0.30 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 89
# Time elapsed to gather jobs: 0.35 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 87
# Time elapsed to gather jobs: 0.30 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 86
# Time elapsed to gather jobs: 0.39 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 85
# Time elapsed to gather jobs: 0.35 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 84
# Time elapsed to gather jobs: 0.34 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 81
# Time elapsed to gather jobs: 0.32 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 78
# Time elapsed to gather jobs: 0.34 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 77
# Time elapsed to gather jobs: 0.36 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 75
# Time elapsed to gather jobs: 0.35 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 74
# Time elapsed to gather jobs: 0.45 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 73
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 73
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 73
# Time elapsed to gather jobs: 0.28 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 72
# Time elapsed to gather jobs: 0.40 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 71
# Time elapsed to gather jobs: 0.35 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 70
# Time elapsed to gather jobs: 0.33 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 69
# Time elapsed to gather jobs: 0.35 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 68
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 68
# Time elapsed to gather jobs: 0.38 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 67
# Time elapsed to gather jobs: 0.37 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 66
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 66
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 50
# Total number of jobs to run : 66
# Time elapsed to gather jobs: 0.33 seconds
# Launching 5 jobs...
# Launched 5 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 61
# Time elapsed to gather jobs: 0.36 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 60
# Time elapsed to gather jobs: 0.35 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 57
# Time elapsed to gather jobs: 0.30 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 57
# Time elapsed to gather jobs: 0.36 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 56
# Time elapsed to gather jobs: 0.30 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 52
# Total number of jobs to run : 53
# Time elapsed to gather jobs: 0.34 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 50
# Time elapsed to gather jobs: 0.30 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 48
# Time elapsed to gather jobs: 0.34 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 47
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 46
# Time elapsed to gather jobs: 0.45 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 45
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 52
# Total number of jobs to run : 45
# Time elapsed to gather jobs: 0.36 seconds
# Launching 3 jobs...
# Launched 3 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 42
# Time elapsed to gather jobs: 0.37 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 40
# Time elapsed to gather jobs: 0.33 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 39
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 39
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 39
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 38
# Time elapsed to gather jobs: 0.42 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 37
# Time elapsed to gather jobs: 0.31 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 35
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 35
# Time elapsed to gather jobs: 0.42 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 35
# Time elapsed to gather jobs: 0.39 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 34
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 34
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 34
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 33
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 33
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 33
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 33
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 33
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 33
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 33
# Time elapsed to gather jobs: 0.40 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 32
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 32
# Time elapsed to gather jobs: 0.31 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 32
# Time elapsed to gather jobs: 0.31 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 31
# Time elapsed to gather jobs: 0.45 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 31
# Time elapsed to gather jobs: 0.35 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 31
# Time elapsed to gather jobs: 0.46 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 30
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 30
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 29
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 29
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 29
# Time elapsed to gather jobs: 0.47 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 29
# Time elapsed to gather jobs: 0.50 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 29
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 29
# Time elapsed to gather jobs: 0.44 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 29
# Time elapsed to gather jobs: 0.35 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 28
# Time elapsed to gather jobs: 0.33 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 27
# Time elapsed to gather jobs: 0.41 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 27
# Time elapsed to gather jobs: 0.31 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 27
# Time elapsed to gather jobs: 0.37 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 26
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 26
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 26
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 53
# Total number of jobs to run : 25
# Time elapsed to gather jobs: 0.38 seconds
# Launching 2 jobs...
# Launched 2 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 23
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 22
# Time elapsed to gather jobs: 0.36 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 21
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 21
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 21
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 21
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 21
# Time elapsed to gather jobs: 0.46 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 20
# Time elapsed to gather jobs: 0.47 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 19
# Time elapsed to gather jobs: 0.38 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 18
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 18
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 18
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 18
# Time elapsed to gather jobs: 0.43 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 18
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 18
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 18
# Time elapsed to gather jobs: 0.37 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.45 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.45 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.47 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.43 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.41 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.35 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.49 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.42 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.35 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 17
# Time elapsed to gather jobs: 0.42 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 16
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 16
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 16
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 16
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 16
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 16
# Time elapsed to gather jobs: 0.40 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 15
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 15
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 15
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 15
# Time elapsed to gather jobs: 0.35 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 14
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 14
# Time elapsed to gather jobs: 0.42 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 14
# Time elapsed to gather jobs: 0.42 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 14
# Time elapsed to gather jobs: 0.40 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.32 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.46 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.45 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 13
# Time elapsed to gather jobs: 0.38 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 12
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 12
# Time elapsed to gather jobs: 0.47 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 12
# Time elapsed to gather jobs: 0.46 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.43 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.47 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.35 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.34 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.41 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.50 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.37 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 11
# Time elapsed to gather jobs: 0.38 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 10
# Time elapsed to gather jobs: 0.47 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 10
# Time elapsed to gather jobs: 0.35 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.40 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.41 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.35 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.39 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.44 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.45 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.38 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.35 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.42 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.46 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.36 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.43 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.35 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.33 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.42 seconds
# Total number of running jobs: 55
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.45 seconds
# Total number of running jobs: 54
# Total number of jobs to run : 9
# Time elapsed to gather jobs: 0.39 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 8
# Time elapsed to gather jobs: 0.39 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 7
# Time elapsed to gather jobs: 0.37 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 54
# Total number of jobs to run : 6
# Time elapsed to gather jobs: 0.32 seconds
# Launching 1 jobs...
# Launched 1 jobs...
# Total number of running jobs: 50
# Total number of jobs to run : 5
# Time elapsed to gather jobs: 0.33 seconds
# Launching 5 jobs...
# Launched 5 jobs...
# Total number of running jobs: 55
# No job to launch left - stopping
